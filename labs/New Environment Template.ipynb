# %%
# %%bash
# # replace prokka_env with the name of your environment
# # replace prokka with whatever package you want to download
# # this may take several minutes, depending on the package
# ENV_NAME=prokka_env
# conda create -y -n $ENV_NAME -c conda-forge -c bioconda -c defaults prokka
# conda install -y -n $ENV_NAME -c anaconda ipykernel
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3/envs/prokka_env
#
#   added / updated specs:
#     - prokka
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     aragorn-1.2.38             |       hec16e2b_5         134 KB  bioconda
#     bedtools-2.30.0            |       h468198e_3        15.5 MB  bioconda
#     blast-2.12.0               |       hf3cf87c_4        22.2 MB  bioconda
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     clustalw-2.1               |       h9f5acd7_7         311 KB  bioconda
#     curl-7.82.0                |       h7bff187_0          90 KB  conda-forge
# ...

# %%
# reload your page, go to the Kernel menu, and choose "Change Kernel"
# your new environment should show up; select it and wait for it to start
# you should now have access to the tools you installed 

# IMPORTANT NOTE: some packages do need additional prerequisites not installed via conda.
# If you receive unexpected behavior, first check the Github/Biostars/Conda pages for open issues
# You may also need to try installing specific versions of programs/channels, i.e.,
#   conda create -n roary_env -c bioconda roary -- DOESN'T WORK (fails when trying to run roary)
#   conda create -n roary_env -c conda-forge -c bioconda roary=3.13 -- DOES WORK (but takes a while)

# %%
# !prokka -h
# Out:
# Option h is ambiguous (help, hmms)
# Name:
#   Prokka 1.14.6 by Torsten Seemann <torsten.seemann@gmail.com>
# Synopsis:
#   rapid bacterial genome annotation
# Usage:
#   prokka [options] <contigs.fasta>
# General:
#   --help             This help
#   --version          Print version and exit
#   --citation         Print citation for referencing Prokka
#   --quiet            No screen output (default OFF)
#   --debug            Debug mode: keep all temporary files (default OFF)
# Setup:
#   --dbdir [X]        Prokka database root folders (default '/root/miniconda3/envs/prokka_env/db')
#   --listdb           List all configured databases
#   --setupdb          Index all installed databases
#   --cleandb          Remove all database indices
#   --depends          List all software dependencies
# Outputs:
#   --outdir [X]       Output folder [auto] (default '')
#   --force            Force overwriting existing output folder (default OFF)
# ...

# %%
# %%bash
# prokka --force lab2/q2.fasta
# Out:
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in PROKKA_04102022/PROKKA_04102022.gbf
# [tbl2asn-forever] Correcting dates in PROKKA_04102022/PROKKA_04102022.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 10-APR-2022
# [13:49:18] This is prokka 1.14.6
# [13:49:18] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [13:49:18] Homepage is https://github.com/tseemann/prokka
# [13:49:18] Local time is Sun Apr 10 13:49:18 2022
# [13:49:18] You are not telling me who you are!
# [13:49:18] Operating system is linux
# [13:49:18] You have BioPerl 1.7.8
# Argument "1.7.8" isn't numeric in numeric lt (<) at /root/miniconda3/envs/prokka_env/bin/prokka line 259.
# [13:49:18] System has 12 cores.
# [13:49:18] Will use maximum of 8 cores.
# [13:49:18] Annotating as >>> Bacteria <<<
# [13:49:18] Generating locus_tag from 'lab2/q2.fasta' contents.
# ...
